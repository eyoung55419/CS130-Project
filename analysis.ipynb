# %%
def load_data():
    for line in open(super_bowl_ads.csv):
        lines = file.readlines()
        for line in open(super_bowl_ads.csv):
            ads_data = line.strip().split(",")
            all_data.append(ads_data)
        return all_data

# %%
ads_data = []
for ad in ads_data[1:]:
    views = float(ad[10])
    if views >= 100000:
        print(ad)
